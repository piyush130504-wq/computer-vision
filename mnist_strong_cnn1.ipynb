# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32') / 255.0   # Normalize to [0,1]
x_test = x_test.astype('float32') / 255.0

# %%
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    x_train, y_train,
    batch_size=128,
    epochs=40,
    validation_data=(x_test, y_test),
    verbose=2
)
# Out:
# Epoch 1/40
# 469/469 - 9s - 19ms/step - accuracy: 0.9279 - loss: 0.2345 - val_accuracy: 0.9829 - val_loss: 0.0505
# Epoch 2/40
# 469/469 - 6s - 12ms/step - accuracy: 0.9752 - loss: 0.0831 - val_accuracy: 0.9876 - val_loss: 0.0382
# Epoch 3/40
# 469/469 - 3s - 7ms/step - accuracy: 0.9808 - loss: 0.0625 - val_accuracy: 0.9887 - val_loss: 0.0327
# Epoch 4/40
# 469/469 - 3s - 7ms/step - accuracy: 0.9843 - loss: 0.0521 - val_accuracy: 0.9890 - val_loss: 0.0318
# Epoch 5/40
# 469/469 - 5s - 11ms/step - accuracy: 0.9866 - loss: 0.0444 - val_accuracy: 0.9904 - val_loss: 0.0294
# Epoch 6/40
# 469/469 - 5s - 12ms/step - accuracy: 0.9879 - loss: 0.0394 - val_accuracy: 0.9909 - val_loss: 0.0296
# Epoch 7/40
# 469/469 - 5s - 10ms/step - accuracy: 0.9890 - loss: 0.0353 - val_accuracy: 0.9914 - val_loss: 0.0283
# Epoch 8/40
# 469/469 - 3s - 7ms/step - accuracy: 0.9903 - loss: 0.0299 - val_accuracy: 0.9907 - val_loss: 0.0288
# Epoch 9/40
# 469/469 - 3s - 7ms/step - accuracy: 0.9913 - loss: 0.0270 - val_accuracy: 0.9917 - val_loss: 0.0285
# Epoch 10/40
# 469/469 - 5s - 11ms/step - accuracy: 0.9915 - loss: 0.0254 - val_accuracy: 0.9917 - val_loss: 0.0251
# Epoch 11/40
# 469/469 - 5s - 11ms/step - accuracy: 0.9927 - loss: 0.0215 - val_accuracy: 0.9922 - val_loss: 0.0277
# Epoch 12/40
# 469/469 - 3s - 7ms/step - accuracy: 0.9928 - loss: 0.0210 - val_accuracy: 0.9926 - val_loss: 0.0254
# Epoch 13/40
# 469/469 - 3s - 6ms/step - accuracy: 0.9932 - loss: 0.0203 - val_accuracy: 0.9924 - val_loss: 0.0245
# Epoch 14/40
# 469/469 - 5s - 11ms/step - accuracy: 0.9936 - loss: 0.0190 - val_accuracy: 0.9923 - val_loss: 0.0266
# Epoch 15/40
# 469/469 - 3s - 7ms/step - accuracy: 0.9943 - loss: 0.0170 - val_accuracy: 0.9921 - val_loss: 0.0260
# Epoch 16/40
# 469/469 - 5s - 11ms/step - accuracy: 0.9949 - loss: 0.0156 - val_accuracy: 0.9923 - val_loss: 0.0297
# Epoch 17/40
# 469/469 - 5s - 11ms/step - accuracy: 0.9942 - loss: 0.0168 - val_accuracy: 0.9921 - val_loss: 0.0282
# Epoch 18/40
# 469/469 - 3s - 7ms/step - accuracy: 0.9949 - loss: 0.0137 - val_accuracy: 0.9925 - val_loss: 0.0286
# Epoch 19/40
# 469/469 - 3s - 7ms/step - accuracy: 0.9949 - loss: 0.0148 - val_accuracy: 0.9929 - val_loss: 0.0287
# Epoch 20/40
# 469/469 - 3s - 6ms/step - accuracy: 0.9956 - loss: 0.0138 - val_accuracy: 0.9925 - val_loss: 0.0263
# Epoch 21/40
# 469/469 - 5s - 11ms/step - accuracy: 0.9955 - loss: 0.0125 - val_accuracy: 0.9928 - val_loss: 0.0302
# Epoch 22/40
# 469/469 - 3s - 7ms/step - accuracy: 0.9951 - loss: 0.0144 - val_accuracy: 0.9925 - val_loss: 0.0300
# Epoch 23/40
# 469/469 - 3s - 7ms/step - accuracy: 0.9958 - loss: 0.0123 - val_accuracy: 0.9933 - val_loss: 0.0299
# Epoch 24/40
# 469/469 - 5s - 12ms/step - accuracy: 0.9963 - loss: 0.0105 - val_accuracy: 0.9921 - val_loss: 0.0345
# Epoch 25/40
# 469/469 - 3s - 6ms/step - accuracy: 0.9961 - loss: 0.0115 - val_accuracy: 0.9913 - val_loss: 0.0354
# Epoch 26/40
# 469/469 - 5s - 11ms/step - accuracy: 0.9959 - loss: 0.0120 - val_accuracy: 0.9921 - val_loss: 0.0332
# Epoch 27/40
# 469/469 - 5s - 11ms/step - accuracy: 0.9964 - loss: 0.0105 - val_accuracy: 0.9931 - val_loss: 0.0327
# Epoch 28/40
# 469/469 - 3s - 7ms/step - accuracy: 0.9971 - loss: 0.0087 - val_accuracy: 0.9928 - val_loss: 0.0362
# Epoch 29/40
# 469/469 - 3s - 6ms/step - accuracy: 0.9965 - loss: 0.0105 - val_accuracy: 0.9934 - val_loss: 0.0305
# Epoch 30/40
# 469/469 - 5s - 11ms/step - accuracy: 0.9966 - loss: 0.0100 - val_accuracy: 0.9939 - val_loss: 0.0299
# Epoch 31/40
# 469/469 - 3s - 7ms/step - accuracy: 0.9976 - loss: 0.0077 - val_accuracy: 0.9932 - val_loss: 0.0303
# Epoch 32/40
# 469/469 - 3s - 6ms/step - accuracy: 0.9968 - loss: 0.0094 - val_accuracy: 0.9930 - val_loss: 0.0323
# Epoch 33/40
# 469/469 - 5s - 11ms/step - accuracy: 0.9972 - loss: 0.0086 - val_accuracy: 0.9935 - val_loss: 0.0373
# Epoch 34/40
# 469/469 - 5s - 11ms/step - accuracy: 0.9969 - loss: 0.0095 - val_accuracy: 0.9933 - val_loss: 0.0330
# Epoch 35/40
# 469/469 - 3s - 7ms/step - accuracy: 0.9972 - loss: 0.0083 - val_accuracy: 0.9935 - val_loss: 0.0389
# Epoch 36/40
# 469/469 - 3s - 7ms/step - accuracy: 0.9970 - loss: 0.0091 - val_accuracy: 0.9931 - val_loss: 0.0324
# Epoch 37/40
# 469/469 - 3s - 6ms/step - accuracy: 0.9971 - loss: 0.0087 - val_accuracy: 0.9947 - val_loss: 0.0296
# Epoch 38/40
# 469/469 - 3s - 6ms/step - accuracy: 0.9978 - loss: 0.0068 - val_accuracy: 0.9941 - val_loss: 0.0303
# Epoch 39/40
# 469/469 - 5s - 11ms/step - accuracy: 0.9973 - loss: 0.0077 - val_accuracy: 0.9937 - val_loss: 0.0339
# Epoch 40/40
# 469/469 - 3s - 7ms/step - accuracy: 0.9978 - loss: 0.0066 - val_accuracy: 0.9921 - val_loss: 0.0365

# %%
model.save('mnist_strong_cnn1.h5')
print("Model saved as mnist_strong_cnn1.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as mnist_strong_cnn1.h5

# %%
from google.colab import files
files.download('mnist_strong_cnn1.h5')
